# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
sns.relplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker", style="smoker", size="size" )
plt.show()

# %%
sns.relplot(data=tips, x="total_bill", y="tip", col="time", hue="sex", style="sex", size="size" )
plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
tips[tips.total_bill==tips.total_bill.max()]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
tips[tips.total_bill==tips.total_bill.min()]
# Out:
#     total_bill  tip     sex smoker  day    time  size
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1

# %%
g=tips.groupby('sex')
g

# %%
g['total_bill'].count()
# Out:
# sex
# Male      157
# Female     87
# Name: total_bill, dtype: int64

# %%
g['sex'].count()
# Out:
# sex
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
g['smoker'].count()
# Out:
# sex
# Male      157
# Female     87
# Name: smoker, dtype: int64

# %%
g.day.count()
# Out:
# sex
# Male      157
# Female     87
# Name: day, dtype: int64

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g.time.count()
# Out:
# sex
# Male      157
# Female     87
# Name: time, dtype: int64

# %%
d=tips.groupby('day')
d

# %%
d['day'].count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: day, dtype: int64

# %%
d['sex'].count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: sex, dtype: int64

# %%
plt.hist(d['day'].count())
# Out:
# (array([1., 0., 0., 0., 0., 0., 1., 0., 1., 1.]),
#  array([19. , 25.8, 32.6, 39.4, 46.2, 53. , 59.8, 66.6, 73.4, 80.2, 87. ]),
#  <a list of 10 Patch objects>)

# %%
tips['sex'].hist(by=tips['smoker'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f279bf26198>,
# ...
#       dtype=object)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips['tip'].hist(by=tips['sex'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f279bcc0240>,
# ...
#       dtype=object)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['smoker'].hist(by=tips['sex'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f27990d6668>,
# ...
#       dtype=object)

# %%
tips['sex'].hist(by=tips['size']).add_legend()
plt.

# %%
sns.set_style('whitegrid')
sns.FacetGrid(tips, hue='sex', size=10).map(plt.scatter, "total_bill", "tip").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
plt.close()
sns.set_style("whitegrid");
sns.pairplot(tips, hue="day", size=4, diag_kind="kde")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('whitegrid')
sns.FacetGrid(tips, hue='day', size=10).map(plt.scatter, "total_bill", "tip").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(tips, hue='time', size=6).map(plt.scatter, "total_bill", "tip").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('whitegrid')
sns.FacetGrid(tips, hue='sex', size=10).map(plt.scatter, "total_bill", "size").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(tips, hue='day', size=10).map(plt.scatter, "total_bill", "tip").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('whitegrid')
sns.FacetGrid(tips, hue='smoker', size=10).map(plt.scatter, "total_bill", "tip").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(tips, hue='sex', size=10).map(plt.scatter, "total_bill", "size").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(tips, hue='smoker', size=10).map(plt.scatter, "total_bill", "size").add_legend();
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
